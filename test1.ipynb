# %%
import yfinance
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File d:\miniconda3\envs\python_tests\lib\site-packages\numpy\_core\__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File d:\miniconda3\envs\python_tests\lib\site-packages\numpy\_core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File d:\miniconda3\envs\python_tests\lib\site-packages\numpy\_core\overrides.py:7
#       6 from .._utils._inspect import getargspec
# ----> 7 from numpy._core._multiarray_umath import (
#       8     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      11 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: No se puede encontrar el módulo especificado.
#
# ...

# %%
import sys
sys.path.append('C:/Users/richa/OneDrive/Escritorio/RICHARD/python/deep_trading/functions')
from download_data import TradingDataDownloader

# Instanciar
downloader = TradingDataDownloader("AAPL", period='1y')

# Descargar y procesar
downloader.download_data()
downloader.calculate_technical_indicators()

# Obtener datos para ML
X, y_binary, y_multi = downloader.get_feature_matrix()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File d:\miniconda3\envs\python_tests\lib\site-packages\numpy\_core\__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File d:\miniconda3\envs\python_tests\lib\site-packages\numpy\_core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File d:\miniconda3\envs\python_tests\lib\site-packages\numpy\_core\overrides.py:7
#       6 from .._utils._inspect import getargspec
# ----> 7 from numpy._core._multiarray_umath import (
#       8     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      11 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: No se puede encontrar el módulo especificado.
#
# ...

# %%
import talib

# %%
# %conda install -c conda-forge ta-lib
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: d:\miniconda3\envs\python_tests
#
#   added / updated specs:
#     - ta-lib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     intel-openmp-2024.2.1      |    h57928b3_1083         1.8 MB  conda-forge
#     libblas-3.9.0              |  32_h641d27c_mkl         3.6 MB  conda-forge
#     libcblas-3.9.0             |  32_h5e41251_mkl         3.6 MB  conda-forge
#     libhwloc-2.9.1             |       h51c2c0f_0         2.4 MB  conda-forge
#     libiconv-1.17              |       h8ffe710_0         698 KB  conda-forge
#     liblapack-3.9.0            |  32_h1aa476e_mkl         3.6 MB  conda-forge
#     libta-lib-0.4.0            |       hcfcfb64_1         4.8 MB  conda-forge
# ...
